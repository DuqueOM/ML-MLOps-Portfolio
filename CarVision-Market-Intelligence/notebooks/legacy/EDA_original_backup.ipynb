# %%
import pandas as pd
import plotly.express as px

st.title("SPRINT 7\n") 
st.header("VEICLES US")
# leer dataset
df = pd.read_csv("../vehicles_us.csv")

# vistazo inicial
df.head()
df.info()
df.describe()

lista = df.columns.tolist()

st.selectbox("Selecciona:", lista)
st.button("Botón")

if st.button("Botón"):
    fig = px.histogram(df, x="odometer", nbins=50, title="Distribución del odómetro")
    st.plotly_chart(fig)

# %%
#st.title("Título") → títulos grandes

#st.header("Encabezado"), st.subheader("Subencabezado")

#st.text("Texto simple"), st.write("Texto, dataframes o lo que quieras")

#st.button("Botón") → devuelve True si lo presionas

#st.checkbox("¿Quieres café?")

#st.radio("Elige uno:", ["Opción A", "Opción B"])

#st.selectbox("Selecciona:", lista)

#st.slider("Rango", min, max, valor_por_defecto)

#st.file_uploader("Sube un archivo")

# %%
fig = px.scatter(df, x="model_year", y="price", title="Precio vs Año del Vehículo")
fig.show()
